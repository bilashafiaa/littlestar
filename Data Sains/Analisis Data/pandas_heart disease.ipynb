# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('D:/heart.csv')

# %%
data
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
data_1 = data[["Oldpeak","HeartDisease"]]
data_1
# Out:
#      Oldpeak  HeartDisease
# 0        0.0             0
# 1        1.0             1
# 2        0.0             0
# 3        1.5             1
# 4        0.0             0
# ..       ...           ...
# 913      1.2             1
# 914      3.4             1
# 915      1.2             1
# 916      0.0             1
# 917      0.0             0
#
# [918 rows x 2 columns]

# %%
data_2 = data_1[data_1["HeartDisease"] == 1]
data_2
# Out:
#      Oldpeak  HeartDisease
# 1        1.0             1
# 3        1.5             1
# 8        1.5             1
# 11       2.0             1
# 13       1.0             1
# ..       ...           ...
# 912      0.2             1
# 913      1.2             1
# 914      3.4             1
# 915      1.2             1
# 916      0.0             1
#
# [508 rows x 2 columns]

# %%
data_3 = data_2[data_2["Oldpeak"] > 0]
data_3.count()
# Out:
# Oldpeak         375
# HeartDisease    375
# dtype: int64

# %%
data_4 = data_2[data_2["Oldpeak"] == 0]
data_4.count()
# Out:
# Oldpeak         124
# HeartDisease    124
# dtype: int64

# %%
data_5 = data_2[data_2["Oldpeak"] < 0]
data_5.count()
# Out:
# Oldpeak         9
# HeartDisease    9
# dtype: int64

# %%
a = np.array([375, 124, 9])
labels = [">0", "=0", "<0"]
colors = ["#00FFFF", "#7FFFD4", "#00CED1"]
plt.pie(a, labels = labels, colors = colors, autopct='%1.2f%%')
plt.show()
